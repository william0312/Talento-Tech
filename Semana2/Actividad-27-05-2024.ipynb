# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Nombres= ['william', 'andres', 'maria','jose','katherine','julian','andrea','luisa','cesar','victor']
Edad= [18, 30, 31, 32, 25, 25, 27, 28, 20, 19]
Genero= ['M', 'M', 'F', 'M', 'F', 'M', 'F', 'F', 'M', 'M']
Estado_Civil=['Casado','Soltero','Casado','Casado','Casado','Soltero','Casado','Casado','Casado','Soltero']
Tipo_vivienda =['Propia','Arriendo','Arriendo','Arriendo','Propia','Arriendo','Propia','Arriendo','Arriendo','Propia']

Data={"Nombres":Nombres,
      "Edad": Edad,
      "Genero": Genero,
      "Estado_Civil": Estado_Civil,
      "Tipo_vivienda": Tipo_vivienda}


df = pd.DataFrame(Data)



# Cantidad de mujeres y hombres
generos = df.groupby(['Genero']).count();
print (generos.Nombres)


#Añade la columna edad en meses
df['Edad_Meses']=df.Edad*24




# Imprime el DataFrame actualizado

df
# Out:
# Genero
# F    4
# M    6
# Name: Nombres, dtype: int64
#      Nombres  Edad Genero Estado_Civil Tipo_vivienda  Edad_Meses
# 0    william    18      M       Casado        Propia         432
# 1     andres    30      M      Soltero      Arriendo         720
# 2      maria    31      F       Casado      Arriendo         744
# 3       jose    32      M       Casado      Arriendo         768
# 4  katherine    25      F       Casado        Propia         600
# 5     julian    25      M      Soltero      Arriendo         600
# 6     andrea    27      F       Casado        Propia         648
# 7      luisa    28      F       Casado      Arriendo         672
# 8      cesar    20      M       Casado      Arriendo         480
# 9     victor    19      M      Soltero        Propia         456
