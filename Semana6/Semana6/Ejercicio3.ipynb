# %%
import keras as k
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
# Generar un conjunto de datos de clasificación sintetico
X, y = make_classification(n_samples=100, n_features=5, n_classes=2)
# Dividir los datos en entrenamiento y prueba
X_trainm, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Convertir la etiquetas a codificación one-hot
X_train = k.utils.to_categorical(y_train)
X_test = k.utils.to_categorical(y_test)

# %%
# Crear una instancia de un modelo secuencial de keras
model = k.models.Sequential()

# %%
# Añanir una capa oculta con 10 neuronas  y relu
model.add(k.layers.Dense(10, activation='relu', input_shape=(X_train.shape[1],)))
# Añadir una capa de salida a con 2 neuronas
model.add(k.layers.Dense(2, activation='softmax'))

# %%
# Compilar el modelo
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Entrenar el modelo
y_train_categorical = k.utils.to_categorical(y_train)
y_test_categorical = k.utils.to_categorical(y_test)
model.fit(X_train, y_train_categorical, epochs=100, batch_size=32, validation_data=(X_test, y_test_categorical))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2900 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2835 - accuracy: 1.0000 - val_loss: 0.3015 - val_accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2772 - accuracy: 1.0000 - val_loss: 0.2952 - val_accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2709 - accuracy: 1.0000 - val_loss: 0.2887 - val_accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2647 - accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2586 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
# Evaluación del modelo
loss, accuracy = model.evaluate(X_test, y_test_categorical)
# Out:
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0333 - accuracy: 1.0000

# %%
# Impresión del resultado
print('Perdida en el conjunto de prueba:', loss)
print('Precisión en el conjunto de prueba:', accuracy)
# Out:
# Perdida en el conjunto de prueba: 0.03327219560742378
# Precisión en el conjunto de prueba: 1.0
