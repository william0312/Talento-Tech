# %%
import numpy as np

# %%
x_input = [2,1,3]
weights=[1,-1,1]
bias=-5


def stepfunction(z):
  step=0
  if z >= 0:
    #step=1
    step=z
  else:
    step=0
  return (step);

  #la funcion step asigana 1 para los x
  #si los deja pasar es relu




def single_neuron_network (weights,bias,x_input):
  output_before_activacion = 0
  sumatoria =0
  for i in range(len(x_input)):
    multiplicacion = weights[i] * x_input[i];
    sumatoria = multiplicacion +sumatoria;
  print ("la sumatoria es: ",sumatoria);
  print ("la z es :",sumatoria + bias)
  z=sumatoria + bias;
  return (z);


z=single_neuron_network (weights,bias,x_input)
a=stepfunction (z)
print ("A:",a)
# Out:
# la sumatoria es:  4
# la z es : -1
# A: 0
